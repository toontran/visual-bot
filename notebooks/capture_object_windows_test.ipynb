# %%
# %matplotlib inline 
import matplotlib.pyplot as plt # To plot images
import cv2 # Image processing library

import sys
sys.path.insert(0, '../') # Access the parent folder

# All source code
from src.img_utils import (extract_object, 
                           extract_all_objects)
from src.visual_bot import VisualBot

# %%
vb = VisualBot()
# Out:
# Loading text_crop_model weights from checkpoint (C:/Users/Welcome/Desktop/pj/sel/CRAFT-pytorch/weights/craft_mlt_25k.pth)
# Loading text_crop_model weights from checkpoint (C:/Users/Welcome/Desktop/pj/sel/deep-text-recognition-benchmark/weights/TPS-ResNet-BiLSTM-CTC.pth)

# %%
scr = vb.capture_screenshot()

# %%
plt.figure(figsize=(100, 50))
plt.imshow(scr)

# %%
scr
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x1BEF09A8D48>

# %%
import pyautogui
import numpy as np

# %%
im = pyautogui.screenshot(region=(5,30, 40, 40))

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=40x40 at 0x1BEF099F188>

# %%
im1 = np.array(im)
image1 = np.array(scr)

# %%
coordinates = extract_object(im1, image1)

# %%
type(im1)
# Out:
# PIL.Image.Image

# %%
type(im)
# Out:
# PIL.Image.Image

# %%
coordinates
# Out:
# ((5, 30), (45, 70))

# %%
plt.imshow(image1[30:70,5:45])
